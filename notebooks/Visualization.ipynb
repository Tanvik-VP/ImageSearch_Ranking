# %%
import os
os.chdir('../')

# %%
from dtd import autopatch
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import cv2
import random

plt.style.use('ggplot')

# %%
DATA_FOLDER = 'data/101_ObjectCategories'

# %%
list(Path(DATA_FOLDER).iterdir())
# Out:
# [PosixPath('data/101_ObjectCategories/gerenuk'),
#  PosixPath('data/101_ObjectCategories/hawksbill'),
#  PosixPath('data/101_ObjectCategories/headphone'),
#  PosixPath('data/101_ObjectCategories/ant'),
#  PosixPath('data/101_ObjectCategories/butterfly'),
#  PosixPath('data/101_ObjectCategories/lamp'),
#  PosixPath('data/101_ObjectCategories/strawberry'),
#  PosixPath('data/101_ObjectCategories/water_lilly'),
#  PosixPath('data/101_ObjectCategories/chandelier'),
#  PosixPath('data/101_ObjectCategories/dragonfly'),
#  PosixPath('data/101_ObjectCategories/crab'),
#  PosixPath('data/101_ObjectCategories/pagoda'),
#  PosixPath('data/101_ObjectCategories/dollar_bill'),
#  PosixPath('data/101_ObjectCategories/emu'),
#  PosixPath('data/101_ObjectCategories/inline_skate'),
#  PosixPath('data/101_ObjectCategories/platypus'),
#  PosixPath('data/101_ObjectCategories/dalmatian'),
#  PosixPath('data/101_ObjectCategories/cup'),
#  PosixPath('data/101_ObjectCategories/airplanes'),
#  PosixPath('data/101_ObjectCategories/joshua_tree'),
#  PosixPath('data/101_ObjectCategories/cougar_body'),
#  PosixPath('data/101_ObjectCategories/grand_piano'),
#  PosixPath('data/101_ObjectCategories/trilobite'),
#  PosixPath('data/101_ObjectCategories/brontosaurus'),
#  PosixPath('data/101_ObjectCategories/wild_cat'),
#  PosixPath('data/101_ObjectCategories/pigeon'),
#  PosixPath('data/101_ObjectCategories/dolphin'),
#  PosixPath('data/101_ObjectCategories/soccer_ball'),
#  PosixPath('data/101_ObjectCategories/wrench'),
#  PosixPath('data/101_ObjectCategories/scorpion'),
#  PosixPath('data/101_ObjectCategories/flamingo_head'),
#  PosixPath('data/101_ObjectCategories/nautilus'),
#  PosixPath('data/101_ObjectCategories/accordion'),
#  PosixPath('data/101_ObjectCategories/cougar_face'),
#  PosixPath('data/101_ObjectCategories/pyramid'),
#  PosixPath('data/101_ObjectCategories/camera'),
#  PosixPath('data/101_ObjectCategories/barrel'),
#  PosixPath('data/101_ObjectCategories/schooner'),
#  PosixPath('data/101_ObjectCategories/cellphone'),
#  PosixPath('data/101_ObjectCategories/panda'),
#  PosixPath('data/101_ObjectCategories/revolver'),
#  PosixPath('data/101_ObjectCategories/lobster'),
#  PosixPath('data/101_ObjectCategories/menorah'),
#  PosixPath('data/101_ObjectCategories/lotus'),
#  PosixPath('data/101_ObjectCategories/stapler'),
#  PosixPath('data/101_ObjectCategories/crocodile'),
#  PosixPath('data/101_ObjectCategories/chair'),
#  PosixPath('data/101_ObjectCategories/helicopter'),
#  PosixPath('data/101_ObjectCategories/minaret'),
#  PosixPath('data/101_ObjectCategories/starfish'),
#  PosixPath('data/101_ObjectCategories/ceiling_fan'),
#  PosixPath('data/101_ObjectCategories/ketch'),
#  PosixPath('data/101_ObjectCategories/mayfly'),
#  PosixPath('data/101_ObjectCategories/wheelchair'),
#  PosixPath('data/101_ObjectCategories/bass'),
#  PosixPath('data/101_ObjectCategories/yin_yang'),
#  PosixPath('data/101_ObjectCategories/crocodile_head'),
#  PosixPath('data/101_ObjectCategories/saxophone'),
#  PosixPath('data/101_ObjectCategories/beaver'),
#  PosixPath('data/101_ObjectCategories/mandolin'),
#  PosixPath('data/101_ObjectCategories/bonsai'),
#  PosixPath('data/101_ObjectCategories/Leopards'),
#  PosixPath('data/101_ObjectCategories/car_side'),
#  PosixPath('data/101_ObjectCategories/ibis'),
#  PosixPath('data/101_ObjectCategories/electric_guitar'),
#  PosixPath('data/101_ObjectCategories/kangaroo'),
#  PosixPath('data/101_ObjectCategories/stegosaurus'),
#  PosixPath('data/101_ObjectCategories/ferry'),
#  PosixPath('data/101_ObjectCategories/snoopy'),
#  PosixPath('data/101_ObjectCategories/umbrella'),
#  PosixPath('data/101_ObjectCategories/rhino'),
#  PosixPath('data/101_ObjectCategories/okapi'),
#  PosixPath('data/101_ObjectCategories/watch'),
#  PosixPath('data/101_ObjectCategories/brain'),
#  PosixPath('data/101_ObjectCategories/gramophone'),
#  PosixPath('data/101_ObjectCategories/scissors'),
#  PosixPath('data/101_ObjectCategories/rooster'),
#  PosixPath('data/101_ObjectCategories/cannon'),
#  PosixPath('data/101_ObjectCategories/binocular'),
#  PosixPath('data/101_ObjectCategories/anchor'),
#  PosixPath('data/101_ObjectCategories/octopus'),
#  PosixPath('data/101_ObjectCategories/buddha'),
#  PosixPath('data/101_ObjectCategories/laptop'),
#  PosixPath('data/101_ObjectCategories/windsor_chair'),
#  PosixPath('data/101_ObjectCategories/hedgehog'),
#  PosixPath('data/101_ObjectCategories/pizza'),
#  PosixPath('data/101_ObjectCategories/euphonium'),
#  PosixPath('data/101_ObjectCategories/stop_sign'),
#  PosixPath('data/101_ObjectCategories/Motorbikes'),
#  PosixPath('data/101_ObjectCategories/sea_horse'),
#  PosixPath('data/101_ObjectCategories/flamingo'),
#  PosixPath('data/101_ObjectCategories/BACKGROUND_Google'),
#  PosixPath('data/101_ObjectCategories/ewer'),
#  PosixPath('data/101_ObjectCategories/garfield'),
#  PosixPath('data/101_ObjectCategories/crayfish'),
#  PosixPath('data/101_ObjectCategories/Faces_easy'),
#  PosixPath('data/101_ObjectCategories/Faces'),
#  PosixPath('data/101_ObjectCategories/sunflower'),
#  PosixPath('data/101_ObjectCategories/llama'),
#  PosixPath('data/101_ObjectCategories/elephant'),
#  PosixPath('data/101_ObjectCategories/tick'),
#  PosixPath('data/101_ObjectCategories/metronome')]

# %%
len(list(Path(DATA_FOLDER).iterdir()))
# Out:
# 102

# %% [markdown]
# ## lets see the distribution of images across class

# %%
background_class = "BACKGROUND_Google"

# %%
all_classes_path = list(filter(lambda x:x.name !=background_class, Path(DATA_FOLDER).iterdir()))

# %%
assert len(all_classes_path) == 101
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/tanvikvp/Documents/Image-search/notebooks/Visualization.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/tanvikvp/Documents/Image-search/notebooks/Visualization.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> assert len(all_classes_path) == 101
#
# AssertionError:

# %%
Path(DATA_FOLDER) / background_class
# Out:
# PosixPath('data/101_ObjectCategories/BACKROUND_Google')

# %%
len(list((Path(DATA_FOLDER) / background_class).iterdir()))
# Out:
# 468

# %% [markdown]
# ## total background images are 468

# %%
all_classes_size = [(class_path.name, len(list(class_path.iterdir()))) for class_path in all_classes_path]

# %%
all_classes_size = sorted(all_classes_size, key=lambda x: -x[1])

# %%
plt.figure(figsize=(25,10))
plt.bar([x[0] for x in all_classes_size], [x[1] for x in all_classes_size])
plt.xticks(rotation=90)
plt.show()

# %%
# total images in dataset
sum(x[1] for x in all_classes_size)
# Out:
# 9145

# %%
# total images in dataset in top 5 classes
sum(x[1] for x in all_classes_size[:5])
# Out:
# 2936

# %%
# 5% of top classes contains 30% of data 
2707/8677
# Out:
# 0.31197418462602283

# %%
def read_image(image_path: Path):
    """
    Returns image in RGB format
    """
    img = cv2.imread(str(image_path))
    if img is not None:
        img = img[:, :, ::-1]
    return img

# %%
random_sample_paths = [random.choices(list(x.iterdir()), k=5) for x in random.choices(all_classes_path, k=5)]

# %%
fig, axarr = plt.subplots(5,5, figsize=(10,10))
for i, each_class in enumerate(random_sample_paths):
    class_name = each_class[0].parent.name
    print(class_name)
    for j, image_path in enumerate(each_class):
        axarr[i, j].imshow(read_image(image_path))
        axarr[i, j].xaxis.set_ticklabels([])
        axarr[i, j].yaxis.set_ticklabels([])
        axarr[i, j].xaxis.set_ticks([])
        axarr[i, j].yaxis.set_ticks([])
        if j==0:
            axarr[i, j].set_ylabel(class_name, size='large')
            axarr[i, j].yaxis.get_label().set_visible(True)
fig.tight_layout()
plt.show()
# Out:
# rhino
# camera
# gramophone
# laptop
# pyramid

# %%
all_images_sizes = [read_image(image_path).shape[:2] for class_path in all_classes_path for image_path in class_path.iterdir()]

# %%
all_images_sizes[:20]
# Out:
# [(188, 300),
#  (225, 300),
#  (200, 300),
#  (167, 300),
#  (300, 294),
#  (300, 265),
#  (222, 300),
#  (300, 253),
#  (300, 253),
#  (211, 300),
#  (300, 273),
#  (300, 298),
#  (223, 300),
#  (176, 300),
#  (225, 300),
#  (279, 300),
#  (300, 198),
#  (153, 300),
#  (180, 300),
#  (300, 261)]

# %%
all_images_aspect_ratio = [x[0]/x[1] for x in all_images_sizes]

# %%
def is_image_grayscale(image):
    return np.all(np.logical_and(image[:,:,0] == image[:,:,1], image[:,:,1] == image[:,:,2]))

# %%
image = (read_image('data/101_ObjectCategories/accordion/image_0001.jpg'))

# %%
all_images_is_grayscale = [[is_image_grayscale(read_image(image_path)) for image_path in class_path.iterdir()] for class_path in all_classes_path ]

# %%
sum([y for x in all_images_is_grayscale for y in x])
# Out:
# 458

# %%
all_classes_grayscale = []
for class_name, is_grayscale in zip(all_classes_path, all_images_is_grayscale):
    all_classes_grayscale.append((class_name.name, sum(is_grayscale), sum(x==False for x in is_grayscale)))

# %%
all_classes_grayscale = sorted(all_classes_grayscale, key=lambda x: -sum(x[1:]))

# %%
list(map(lambda x: sum(x[1:]), all_classes_grayscale))
# Out:
# [800,
#  798,
#  468,
#  435,
#  435,
#  239,
#  200,
#  128,
#  123,
#  114,
#  107,
#  100,
#  99,
#  98,
#  91,
#  88,
#  87,
#  86,
#  86,
#  86,
#  85,
#  85,
#  85,
#  84,
#  82,
#  81,
#  80,
#  78,
#  76,
#  75,
#  75,
#  73,
#  70,
#  69,
#  68,
#  67,
#  67,
#  67,
#  66,
#  65,
#  64,
#  64,
#  64,
#  64,
#  64,
#  63,
#  62,
#  61,
#  60,
#  59,
#  59,
#  59,
#  59,
#  57,
#  57,
#  57,
#  56,
#  55,
#  55,
#  54,
#  54,
#  53,
#  53,
#  52,
#  51,
#  51,
#  50,
#  50,
#  49,
#  49,
#  47,
#  47,
#  47,
#  47,
#  46,
#  45,
#  45,
#  45,
#  43,
#  43,
#  43,
#  42,
#  42,
#  42,
#  41,
#  40,
#  40,
#  39,
#  39,
#  39,
#  38,
#  37,
#  35,
#  35,
#  35,
#  34,
#  34,
#  34,
#  34,
#  33,
#  32,
#  31]

# %%
fig, axis = plt.subplots(figsize=(25,10))
axis.bar([x[0] for x in all_classes_grayscale], [x[2]+x[1] for x in all_classes_grayscale], label='color_images')
axis.bar([x[0] for x in all_classes_grayscale], [x[1] for x in all_classes_grayscale], label='greyscale_images')
axis.legend()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
