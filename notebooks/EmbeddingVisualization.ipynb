# %%
import os
os.chdir('../')

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
embeddings = np.load('data/embeddings.npy')
labels = np.load('data/embeddings.labels.npy')

# %%
labels
# Out:
# array(['BACKGROUND_Google', 'BACKGROUND_Google', 'BACKGROUND_Google', ...,
#        'yin_yang', 'yin_yang', 'yin_yang'], dtype='<U17')

# %%
t = PCA(n_components= 2, random_state=2023)

# %%
new_embeddings = t.fit_transform(embeddings)

# %%
t.explained_variance_
# Out:
# array([17.611305, 15.697976], dtype=float32)

# %%
t.explained_variance_ratio_
# Out:
# array([0.04551021, 0.04056588], dtype=float32)

# %%
new_embeddings
# Out:
# array([[ 1.9437134 ,  1.0840204 ],
#        [ 1.9764379 ,  2.2553358 ],
#        [-1.5642533 , -2.067377  ],
#        ...,
#        [ 1.9090157 , -0.70908934],
#        [ 0.80941236, -1.2171078 ],
#        [ 0.89389265,  0.03006561]], dtype=float32)

# %%
fig, ax = plt.subplots(figsize=(25,30))
ax.margins(0.05)
for label in set(labels):
    x = embeddings[labels==label]
    ax.plot(x[:, 0], x[:, 1], marker='o', linestyle='', ms=9, label=label)
ax.legend()
plt.show()

# %% [markdown]
# ## Exporting Embeddings and Labels for Tensorflow Projector

# %%
np.savetxt('data/embeddings.txt', embeddings, delimiter='\t')

# %%
np.savetxt('data/embeddings.labels.txt', labels, delimiter='\t', fmt='%s')
